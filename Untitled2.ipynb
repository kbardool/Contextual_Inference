# %%
"""
Mask R-CNN
Configurations and data loading code for MS COCO.

Copyright (c) 2017 Matterport, Inc.
Licensed under the MIT License (see LICENSE for details)
Written by Waleed Abdulla

------------------------------------------------------------

Usage: import the module (see Jupyter notebooks for examples), or run from
       the command line as such:

    # Train a new model starting from pre-trained COCO weights
    python3 coco.py train --dataset=/path/to/coco/ --model=coco

    # Train a new model starting from ImageNet weights
    python3 coco.py train --dataset=/path/to/coco/ --model=imagenet

    # Continue training a model that you had trained earlier
    python3 coco.py train --dataset=/path/to/coco/ --model=/path/to/weights.h5

    # Continue training the last model you trained
    python3 coco.py train --dataset=/path/to/coco/ --model=last

    # Run COCO evaluatoin on the last model you trained
    python3 coco.py evaluate --dataset=/path/to/coco/ --model=last
"""

import os
import time
import numpy as np
# %load_ext autoreload
# %autoreload 1
print(' breakpoint 1')
# Download and install the Python COCO tools from https://github.com/waleedka/coco
# That's a fork from the original https://github.com/pdollar/coco with a bug
# fix for Python 3.
# I submitted a pull request https://github.com/cocodataset/cocoapi/pull/50
# If the PR is merged then use the original repo.
# Note: Edit PythonAPI/Makefile and replace "python" with "python3".
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from pycocotools import mask as maskUtils

from   mrcnn.config import Config
import mrcnn.utils as utils
import mrcnn.model as modellib
import mrcnn.dataset as dataset

# Root directory of the project
ROOT_DIR = os.getcwd()

# Path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Directory to save logs and model checkpoints, if not provided
# through the command line argument --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")
# Out:
#  breakpoint 1

# %%
from coco import CocoDataset, CocoConfig, evaluate_coco, build_coco_results
import pprint as pp
pp = pp.PrettyPrinter(indent=4)
import argparse

# Parse command line arguments
parser = argparse.ArgumentParser(description='Train Mask R-CNN on MS COCO.')
parser.add_argument("command",
                    metavar="<command>",
                    help="'train' or 'evaluate' on MS COCO")
parser.add_argument('--dataset', required=True,
                    metavar="/path/to/coco/",
                    help='Directory of the MS-COCO dataset')
parser.add_argument('--model', required=True,
                    metavar="/path/to/weights.h5",
                    help="Path to weights .h5 file or 'coco'")
parser.add_argument('--logs', required=False,
                    default=DEFAULT_LOGS_DIR,
                    metavar="/path/to/logs/",
                    help='Logs and checkpoints directory (default=logs/)')
parser.add_argument('--limit', required=False,
                    default=500,
                    metavar="<image count>",
                    help='Images to use for evaluation (defaults=500)')
# args = parser.parse_args()
args = parser.parse_args("train --dataset E:\MLDatasets\coco2014 --model mask_rcnn_coco.h5 --limit 10".split())
# pp.pprint(options)
pp.pprint(args)
print("Model:   ", args.model)
print("Dataset: ", args.dataset)
print("Logs:    ", args.logs)
print("Limit:   ", args.limit)

# Configurations
# Out:
# Namespace(command='train', dataset='E:\\MLDatasets\\coco2014', limit='10', logs='E:\\git_projs\\Mask_RCNN_2\\logs', model='mask_rcnn_coco.h5')
# Model:    mask_rcnn_coco.h5
# Dataset:  E:\MLDatasets\coco2014
# Logs:     E:\git_projs\Mask_RCNN_2\logs
# Limit:    10

# %%
# Configurations
if args.command == "train":
    config = CocoConfig()
else:
    class InferenceConfig(CocoConfig):
        # Set batch size to 1 since we'll be running inference on
        # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
        GPU_COUNT = 1
        IMAGES_PER_GPU = 1
        DETECTION_MIN_CONFIDENCE = 0
    config = InferenceConfig()
config.display()

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
# tf_config = tf.ConfigProto()
# tf_config.gpu_options.per_process_gpu_memory_fraction = 0.55
# set_session(tf.Session(config=tf_config))

gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.55)
set_session(tf.Session(config=tf.ConfigProto(gpu_options=gpu_options)))
# Out:
# Configurations:
# BACKBONE_SHAPES                [[256 256]
#  [128 128]
#  [ 64  64]
#  [ 32  32]
#  [ 16  16]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# GPU_COUNT                      1
# IMAGES_PER_GPU                 2
# IMAGE_MAX_DIM                  1024
# IMAGE_MIN_DIM                  800
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
# Create model
if args.command == "train":
    print('setup model for Training ')
    model = modellib.MaskRCNN(mode="training", config=config,
                              model_dir=args.logs)
else:
    print('setup model for Inference ')
    model = modellib.MaskRCNN(mode="inference", config=config,
                              model_dir=args.logs)
# Out:
# setup model for Training
#  IMAGE SHAPE is : 1024    1024

# %%
# for layer in model.keras_model.layers
#     print layer.name 
mdl = model.keras_model
layers    = [layer for layer in mdl.layers]          # all layer outputs
len(layers)
# Out:
# 406

# %%
print(' layer {} :  {}'.format(idx,layers[0]))
pp.pprint(layers[0]._inbound_nodes[0].__dict__)
pp.pprint(layers[0].__dict__)
print('-------------------------------------------')
# Out:
#  layer 405 :  <keras.engine.topology.InputLayer object at 0x000002E98F24DEF0>
# {   'arguments': None,
#     'inbound_layers': [],
#     'input_masks': [None],
#     'input_shapes': [(None, 1024, 1024, 3)],
#     'input_tensors': [   <tf.Tensor 'input_image_2:0' shape=(?, 1024, 1024, 3) dtype=float32>],
#     'node_indices': [],
#     'outbound_layer': <keras.engine.topology.InputLayer object at 0x000002E98F24DEF0>,
#     'output_masks': [None],
#     'output_shapes': [(None, 1024, 1024, 3)],
#     'output_tensors': [   <tf.Tensor 'input_image_2:0' shape=(?, 1024, 1024, 3) dtype=float32>],
#     'tensor_indices': []}
# {   '_built': True,
#     '_inbound_nodes': [   <keras.engine.topology.Node object at 0x000002E98F21BBE0>],
#     '_initial_weights': None,
#     '_losses': [],
#     '_non_trainable_weights': [],
#     '_outbound_nodes': [   <keras.engine.topology.Node object at 0x000002E988669828>],
#     '_per_input_losses': {},
#     '_per_input_updates': {},
#     '_trainable_weights': [],
#     '_updates': [],
#     'batch_input_shape': (None, 1024, 1024, 3),
#     'dtype': 'float32',
#     'input_spec': None,
#     'is_placeholder': True,
#     'name': 'input_image',
#     'sparse': False,
#     'stateful': False,
#     'supports_masking': False,
#     'trainable': False}
# -------------------------------------------

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
for idx,layer in enumerate(layers):
    print('>layer {} : name : {}  type: {}'.format(idx,layer.name,layer))
#     pp.pprint(layer._inbound_nodes[0].__dict__)
    print(">> input_shape {} inbound node {} ".format(layer._inbound_nodes[0].input_shapes,layer._inbound_nodes[0]))
#     print('>> inbound node output_shape {}'.format(layer._inbound_nodes[0].output_shapes))
#     if isinstance("layer", mrcnn.model.BatchNorm):
#         print('Batch Nomraliation layer')
    if 'padding' in layer.__dict__:
        print('\t padding : ',layer.padding)
    if 'filters' in layer.__dict__:
        print('\t Filters : ',layer.filters, ' Kernel Size :', layer.kernel_size, 'Stride:', layer.strides, ' Shape',layer.kernel.shape)
    
    if 'activation' in layer.__dict__:
        print('\t ',layer.activation)
    if 'pool_size' in layer.__dict__:
        print('\t poolsize : ',layer.pool_size,'Stride:', layer.strides)

#     pp.pprint(layer.__dict__)
    print("<< outbound shape{} input_shape {}".format(layer._outbound_nodes[0].input_shapes,layer._outbound_nodes[0]))
#     print('<< outbound node output_shape {}'.format(layer._outbound_nodes[0].output_shapes))
    print('-------------------------------------------')
    #layer.name, layer.input._keras_shape, layer.output._keras_shape
# Out:
# >layer 0 : name : input_image  type: <keras.engine.topology.InputLayer object at 0x000002E98F24DEF0>
# >> input_shape [(None, 1024, 1024, 3)] inbound node <keras.engine.topology.Node object at 0x000002E98F21BBE0>
# << outbound shape[(None, 1024, 1024, 3)] input_shape <keras.engine.topology.Node object at 0x000002E988669828>
# -------------------------------------------
# >layer 1 : name : zero_padding2d_3  type: <keras.layers.convolutional.ZeroPadding2D object at 0x000002E98F2250B8>
# >> input_shape [(None, 1024, 1024, 3)] inbound node <keras.engine.topology.Node object at 0x000002E988669828>
# 	 padding :  ((3, 3), (3, 3))
# << outbound shape[(None, 1030, 1030, 3)] input_shape <keras.engine.topology.Node object at 0x000002E988675780>
# -------------------------------------------
# >layer 2 : name : conv1  type: <keras.layers.convolutional.Conv2D object at 0x000002E98F225CC0>
# >> input_shape [(None, 1030, 1030, 3)] inbound node <keras.engine.topology.Node object at 0x000002E988675780>
# 	 padding :  valid
# 	 Filters :  64  Kernel Size : (7, 7) Stride: (2, 2)  Shape (7, 7, 3, 64)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 512, 512, 64)] input_shape <keras.engine.topology.Node object at 0x000002E988682B00>
# -------------------------------------------
# >layer 3 : name : bn_conv1  type: <mrcnn.model.BatchNorm object at 0x000002E9886699B0>
# >> input_shape [(None, 512, 512, 64)] inbound node <keras.engine.topology.Node object at 0x000002E988682B00>
# << outbound shape[(None, 512, 512, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9886CAB38>
# -------------------------------------------
# >layer 4 : name : activation_149  type: <keras.layers.core.Activation object at 0x000002E98868F7B8>
# >> input_shape [(None, 512, 512, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9886CAB38>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 512, 512, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9886A6470>
# -------------------------------------------
# >layer 5 : name : max_pooling2d_3  type: <keras.layers.pooling.MaxPooling2D object at 0x000002E98869BDD8>
# >> input_shape [(None, 512, 512, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9886A6470>
# 	 padding :  same
# 	 poolsize :  (3, 3) Stride: (2, 2)
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9886E8CC0>
# -------------------------------------------
# >layer 6 : name : res2a_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E988682DA0>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9886E8CC0>
# 	 padding :  valid
# 	 Filters :  64  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 64, 64)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9886DAF28>
# -------------------------------------------
# >layer 7 : name : bn2a_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E9886BD898>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9886DAF28>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9886DAE48>
# -------------------------------------------
# >layer 8 : name : activation_150  type: <keras.layers.core.Activation object at 0x000002E9886FEE80>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9886DAE48>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E988716470>
# -------------------------------------------
# >layer 9 : name : res2a_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E9886FEE10>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E988716470>
# 	 padding :  same
# 	 Filters :  64  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 64, 64)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9887426A0>
# -------------------------------------------
# >layer 10 : name : bn2a_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E988726E10>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9887426A0>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E988742518>
# -------------------------------------------
# >layer 11 : name : activation_151  type: <keras.layers.core.Activation object at 0x000002E988751E80>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E988742518>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E988768BE0>
# -------------------------------------------
# >layer 12 : name : res2a_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E988742B38>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E988768BE0>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 64, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E98879E9E8>
# -------------------------------------------
# >layer 13 : name : res2a_branch1  type: <keras.layers.convolutional.Conv2D object at 0x000002E9887BAB70>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9887C5320>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 64, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9888179E8>
# -------------------------------------------
# >layer 14 : name : bn2a_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E988780630>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E98879E9E8>
# << outbound shape[(None, 256, 256, 256), (None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9888474E0>
# -------------------------------------------
# >layer 15 : name : bn2a_branch1  type: <mrcnn.model.BatchNorm object at 0x000002E9887ACE48>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9888179E8>
# << outbound shape[(None, 256, 256, 256), (None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9888474E0>
# -------------------------------------------
# >layer 16 : name : add_67  type: <keras.layers.merge.Add object at 0x000002E9887FACF8>
# >> input_shape [(None, 256, 256, 256), (None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9888474E0>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E98883B208>
# -------------------------------------------
# >layer 17 : name : res2a_out  type: <keras.layers.core.Activation object at 0x000002E988817F28>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E98883B208>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E988821898>
# -------------------------------------------
# >layer 18 : name : res2b_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E9888091D0>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E988821898>
# 	 padding :  valid
# 	 Filters :  64  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 256, 64)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E98888CDA0>
# -------------------------------------------
# >layer 19 : name : bn2b_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E98882CD68>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E98888CDA0>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E98888C4E0>
# -------------------------------------------
# >layer 20 : name : activation_152  type: <keras.layers.core.Activation object at 0x000002E988821748>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E98888C4E0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9888957B8>
# -------------------------------------------
# >layer 21 : name : res2b_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E988864080>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9888957B8>
# 	 padding :  same
# 	 Filters :  64  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 64, 64)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9888C2C88>
# -------------------------------------------
# >layer 22 : name : bn2b_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E988871C50>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9888C2C88>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9888C2CF8>
# -------------------------------------------
# >layer 23 : name : activation_153  type: <keras.layers.core.Activation object at 0x000002E9888CEF60>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9888C2CF8>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9888FE5F8>
# -------------------------------------------
# >layer 24 : name : res2b_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E9888C2B38>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9888FE5F8>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 64, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E98891CF98>
# -------------------------------------------
# >layer 25 : name : bn2b_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E9888F49B0>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E98891CF98>
# << outbound shape[(None, 256, 256, 256), (None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E98896A5F8>
# -------------------------------------------
# >layer 26 : name : add_68  type: <keras.layers.merge.Add object at 0x000002E988929EB8>
# >> input_shape [(None, 256, 256, 256), (None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E98896A5F8>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E98895D2E8>
# -------------------------------------------
# >layer 27 : name : res2b_out  type: <keras.layers.core.Activation object at 0x000002E98891CDD8>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E98895D2E8>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E988943CF8>
# -------------------------------------------
# >layer 28 : name : res2c_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E988938BE0>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E988943CF8>
# 	 padding :  valid
# 	 Filters :  64  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 256, 64)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E988992D68>
# -------------------------------------------
# >layer 29 : name : bn2c_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E988977780>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E988992D68>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9889927F0>
# -------------------------------------------
# >layer 30 : name : activation_154  type: <keras.layers.core.Activation object at 0x000002E98899F668>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9889927F0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9889C5A20>
# -------------------------------------------
# >layer 31 : name : res2c_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E988992D30>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9889C5A20>
# 	 padding :  same
# 	 Filters :  64  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 64, 64)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9889EE898>
# -------------------------------------------
# >layer 32 : name : bn2c_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E9889AEAC8>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9889EE898>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E9889EEB38>
# -------------------------------------------
# >layer 33 : name : activation_155  type: <keras.layers.core.Activation object at 0x000002E9889E29E8>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E9889EEB38>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 64)] input_shape <keras.engine.topology.Node object at 0x000002E988A14DA0>
# -------------------------------------------
# >layer 34 : name : res2c_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E9889EEC50>
# >> input_shape [(None, 256, 256, 64)] inbound node <keras.engine.topology.Node object at 0x000002E988A14DA0>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 64, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E988A3CCF8>
# -------------------------------------------
# >layer 35 : name : bn2c_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E988A2E278>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E988A3CCF8>
# << outbound shape[(None, 256, 256, 256), (None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E988A8B588>
# -------------------------------------------
# >layer 36 : name : add_69  type: <keras.layers.merge.Add object at 0x000002E988A4CEF0>
# >> input_shape [(None, 256, 256, 256), (None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E988A8B588>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E988A725C0>
# -------------------------------------------
# >layer 37 : name : res2c_out  type: <keras.layers.core.Activation object at 0x000002E988A5C710>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E988A725C0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 256, 256, 256)] input_shape <keras.engine.topology.Node object at 0x000002E988A97898>
# -------------------------------------------
# >layer 38 : name : res3a_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E988A72F60>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E988A97898>
# 	 padding :  valid
# 	 Filters :  128  Kernel Size : (1, 1) Stride: (2, 2)  Shape (1, 1, 256, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988AA82B0>
# -------------------------------------------
# >layer 39 : name : bn3a_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E988A66940>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988AA82B0>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988AA88D0>
# -------------------------------------------
# >layer 40 : name : activation_156  type: <keras.layers.core.Activation object at 0x000002E988AB4E48>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988AA88D0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988ACCBE0>
# -------------------------------------------
# >layer 41 : name : res3a_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E988AA8B00>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988ACCBE0>
# 	 padding :  same
# 	 Filters :  128  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 128, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988B029E8>
# -------------------------------------------
# >layer 42 : name : bn3a_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E988AE6630>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988B029E8>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988B02B00>
# -------------------------------------------
# >layer 43 : name : activation_157  type: <keras.layers.core.Activation object at 0x000002E988B1FB38>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988B02B00>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988B42B38>
# -------------------------------------------
# >layer 44 : name : res3a_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E988B02D30>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988B42B38>
# 	 padding :  valid
# 	 Filters :  512  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 128, 512)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988B86F28>
# -------------------------------------------
# >layer 45 : name : res3a_branch1  type: <keras.layers.convolutional.Conv2D object at 0x000002E988B424A8>
# >> input_shape [(None, 256, 256, 256)] inbound node <keras.engine.topology.Node object at 0x000002E988B78828>
# 	 padding :  valid
# 	 Filters :  512  Kernel Size : (1, 1) Stride: (2, 2)  Shape (1, 1, 256, 512)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988BE2BA8>
# -------------------------------------------
# >layer 46 : name : bn3a_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E988B11E48>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988B86F28>
# << outbound shape[(None, 128, 128, 512), (None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988BE2C18>
# -------------------------------------------
# >layer 47 : name : bn3a_branch1  type: <mrcnn.model.BatchNorm object at 0x000002E988B5DEF0>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988BE2BA8>
# << outbound shape[(None, 128, 128, 512), (None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988BE2C18>
# -------------------------------------------
# >layer 48 : name : add_70  type: <keras.layers.merge.Add object at 0x000002E988B9FFD0>
# >> input_shape [(None, 128, 128, 512), (None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988BE2C18>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988C08BE0>
# -------------------------------------------
# >layer 49 : name : res3a_out  type: <keras.layers.core.Activation object at 0x000002E988BE2550>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988C08BE0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988C14B70>
# -------------------------------------------
# >layer 50 : name : res3b_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E988BE2CC0>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988C14B70>
# 	 padding :  valid
# 	 Filters :  128  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 512, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988C25CF8>
# -------------------------------------------
# >layer 51 : name : bn3b_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E988BEE320>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988C25CF8>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988C71978>
# -------------------------------------------
# >layer 52 : name : activation_158  type: <keras.layers.core.Activation object at 0x000002E988C2FFD0>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988C71978>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988C54A20>
# -------------------------------------------
# >layer 53 : name : res3b_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E988C3FC88>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988C54A20>
# 	 padding :  same
# 	 Filters :  128  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 128, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988C80C50>
# -------------------------------------------
# >layer 54 : name : bn3b_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E988C49358>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988C80C50>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988CB3EF0>
# -------------------------------------------
# >layer 55 : name : activation_159  type: <keras.layers.core.Activation object at 0x000002E988C8FCC0>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988CB3EF0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988CC1358>
# -------------------------------------------
# >layer 56 : name : res3b_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E988C80CF8>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988CC1358>
# 	 padding :  valid
# 	 Filters :  512  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 128, 512)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988CEB518>
# -------------------------------------------
# >layer 57 : name : bn3b_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E988C9D668>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988CEB518>
# << outbound shape[(None, 128, 128, 512), (None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988CEB278>
# -------------------------------------------
# >layer 58 : name : add_71  type: <keras.layers.merge.Add object at 0x000002E988CC1A20>
# >> input_shape [(None, 128, 128, 512), (None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988CEB278>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988D2BCF8>
# -------------------------------------------
# >layer 59 : name : res3b_out  type: <keras.layers.core.Activation object at 0x000002E988D01D30>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988D2BCF8>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988D35C88>
# -------------------------------------------
# >layer 60 : name : res3c_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E988CEBC50>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988D35C88>
# 	 padding :  valid
# 	 Filters :  128  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 512, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988D45780>
# -------------------------------------------
# >layer 61 : name : bn3c_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E988D10438>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988D45780>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988D456D8>
# -------------------------------------------
# >layer 62 : name : activation_160  type: <keras.layers.core.Activation object at 0x000002E988D62A90>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988D456D8>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988D79E10>
# -------------------------------------------
# >layer 63 : name : res3c_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E988D456A0>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988D79E10>
# 	 padding :  same
# 	 Filters :  128  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 128, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988DBED68>
# -------------------------------------------
# >layer 64 : name : bn3c_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E988D922E8>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988DBED68>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988DBE1D0>
# -------------------------------------------
# >layer 65 : name : activation_161  type: <keras.layers.core.Activation object at 0x000002E988D86400>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988DBE1D0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E988DC9F28>
# -------------------------------------------
# >layer 66 : name : res3c_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E988DBE748>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E988DC9F28>
# 	 padding :  valid
# 	 Filters :  512  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 128, 512)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988E0CD68>
# -------------------------------------------
# >layer 67 : name : bn3c_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E988DE1B70>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988E0CD68>
# << outbound shape[(None, 128, 128, 512), (None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988E0C3C8>
# -------------------------------------------
# >layer 68 : name : add_72  type: <keras.layers.merge.Add object at 0x000002E988DC9B70>
# >> input_shape [(None, 128, 128, 512), (None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988E0C3C8>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988E4BE10>
# -------------------------------------------
# >layer 69 : name : res3c_out  type: <keras.layers.core.Activation object at 0x000002E988E22F60>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988E4BE10>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E988E57DA0>
# -------------------------------------------
# >layer 70 : name : res3d_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E988E0C860>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E988E57DA0>
# 	 padding :  valid
# 	 Filters :  128  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 512, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E990237B70>
# -------------------------------------------
# >layer 71 : name : bn3d_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E988E31550>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E990237B70>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E990283400>
# -------------------------------------------
# >layer 72 : name : activation_162  type: <keras.layers.core.Activation object at 0x000002E990253C88>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E990283400>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E99026BEF0>
# -------------------------------------------
# >layer 73 : name : res3d_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E990243A20>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E99026BEF0>
# 	 padding :  same
# 	 Filters :  128  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 128, 128)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E9902BBEF0>
# -------------------------------------------
# >layer 74 : name : bn3d_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E99025E748>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E9902BBEF0>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E9902E1B38>
# -------------------------------------------
# >layer 75 : name : activation_163  type: <keras.layers.core.Activation object at 0x000002E99026BF28>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E9902E1B38>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 128)] input_shape <keras.engine.topology.Node object at 0x000002E9902ADE48>
# -------------------------------------------
# >layer 76 : name : res3d_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E9902C7240>
# >> input_shape [(None, 128, 128, 128)] inbound node <keras.engine.topology.Node object at 0x000002E9902ADE48>
# 	 padding :  valid
# 	 Filters :  512  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 128, 512)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E990324588>
# -------------------------------------------
# >layer 77 : name : bn3d_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E990293EF0>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E990324588>
# << outbound shape[(None, 128, 128, 512), (None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E99032F9B0>
# -------------------------------------------
# >layer 78 : name : add_73  type: <keras.layers.merge.Add object at 0x000002E9902D2C50>
# >> input_shape [(None, 128, 128, 512), (None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E99032F9B0>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E9902FD3C8>
# -------------------------------------------
# >layer 79 : name : res3d_out  type: <keras.layers.core.Activation object at 0x000002E990309780>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E9902FD3C8>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 128, 128, 512)] input_shape <keras.engine.topology.Node object at 0x000002E99033C208>
# -------------------------------------------
# >layer 80 : name : res4a_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E990324668>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E99033C208>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (2, 2)  Shape (1, 1, 512, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E990374B00>
# -------------------------------------------
# >layer 81 : name : bn4a_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E99034BEB8>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E990374B00>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99038ADA0>
# -------------------------------------------
# >layer 82 : name : activation_164  type: <keras.layers.core.Activation object at 0x000002E99035AE10>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99038ADA0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E990399208>
# -------------------------------------------
# >layer 83 : name : res4a_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E990374400>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E990399208>
# 	 padding :  same
# 	 Filters :  256  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 256, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9903CF9B0>
# -------------------------------------------
# >layer 84 : name : bn4a_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E990366F98>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9903CF9B0>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9903C2080>
# -------------------------------------------
# >layer 85 : name : activation_165  type: <keras.layers.core.Activation object at 0x000002E9903B3AC8>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9903C2080>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9903F3320>
# -------------------------------------------
# >layer 86 : name : res4a_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E9903D9DA0>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9903F3320>
# 	 padding :  valid
# 	 Filters :  1024  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 256, 1024)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E99042AE10>
# -------------------------------------------
# >layer 87 : name : res4a_branch1  type: <keras.layers.convolutional.Conv2D object at 0x000002E990437710>
# >> input_shape [(None, 128, 128, 512)] inbound node <keras.engine.topology.Node object at 0x000002E990451AC8>
# 	 padding :  valid
# 	 Filters :  1024  Kernel Size : (1, 1) Stride: (2, 2)  Shape (1, 1, 512, 1024)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E990487C50>
# -------------------------------------------
# >layer 88 : name : bn4a_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E990401D30>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E99042AE10>
# << outbound shape[(None, 64, 64, 1024), (None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9904ACB70>
# -------------------------------------------
# >layer 89 : name : bn4a_branch1  type: <mrcnn.model.BatchNorm object at 0x000002E99041C4E0>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E990487C50>
# << outbound shape[(None, 64, 64, 1024), (None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9904ACB70>
# -------------------------------------------
# >layer 90 : name : add_74  type: <keras.layers.merge.Add object at 0x000002E990494B00>
# >> input_shape [(None, 64, 64, 1024), (None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9904ACB70>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9904B9780>
# -------------------------------------------
# >layer 91 : name : res4a_out  type: <keras.layers.core.Activation object at 0x000002E9904797B8>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9904B9780>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E99049F1D0>
# -------------------------------------------
# >layer 92 : name : res4b_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E99046A630>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E99049F1D0>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 1024, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9904F2DD8>
# -------------------------------------------
# >layer 93 : name : bn4b_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E9904B9C88>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9904F2DD8>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E990523668>
# -------------------------------------------
# >layer 94 : name : activation_166  type: <keras.layers.core.Activation object at 0x000002E9904E5940>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E990523668>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99050A7F0>
# -------------------------------------------
# >layer 95 : name : res4b_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E9904D5F60>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99050A7F0>
# 	 padding :  same
# 	 Filters :  256  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 256, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E990565DA0>
# -------------------------------------------
# >layer 96 : name : bn4b_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E9904FEE48>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E990565DA0>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9905654E0>
# -------------------------------------------
# >layer 97 : name : activation_167  type: <keras.layers.core.Activation object at 0x000002E99050A518>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9905654E0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9905707B8>
# -------------------------------------------
# >layer 98 : name : res4b_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E99053F438>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9905707B8>
# 	 padding :  valid
# 	 Filters :  1024  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 256, 1024)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E99059CC88>
# -------------------------------------------
# >layer 99 : name : bn4b_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E99054EC50>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E99059CC88>
# << outbound shape[(None, 64, 64, 1024), (None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9905C12E8>
# -------------------------------------------
# >layer 100 : name : add_75  type: <keras.layers.merge.Add object at 0x000002E9905A8F60>
# >> input_shape [(None, 64, 64, 1024), (None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9905C12E8>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9905CE9B0>
# -------------------------------------------
# >layer 101 : name : res4b_out  type: <keras.layers.core.Activation object at 0x000002E9905B66A0>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9905CE9B0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9905D97B8>
# -------------------------------------------
# >layer 102 : name : res4c_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E99059CCF8>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9905D97B8>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 1024, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99062B240>
# -------------------------------------------
# >layer 103 : name : bn4c_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E9905CE2E8>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99062B240>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E990645BA8>
# -------------------------------------------
# >layer 104 : name : activation_168  type: <keras.layers.core.Activation object at 0x000002E9905F6CC0>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E990645BA8>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9906108D0>
# -------------------------------------------
# >layer 105 : name : res4c_branch2b  type: <keras.layers.convolutional.Conv2D object at 0x000002E99062BA20>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9906108D0>
# 	 padding :  same
# 	 Filters :  256  Kernel Size : (3, 3) Stride: (1, 1)  Shape (3, 3, 256, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99066ED68>
# -------------------------------------------
# >layer 106 : name : bn4c_branch2b  type: <mrcnn.model.BatchNorm object at 0x000002E990604550>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99066ED68>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99066E7F0>
# -------------------------------------------
# >layer 107 : name : activation_169  type: <keras.layers.core.Activation object at 0x000002E99067A668>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99066E7F0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99069EA20>
# -------------------------------------------
# >layer 108 : name : res4c_branch2c  type: <keras.layers.convolutional.Conv2D object at 0x000002E99066ED30>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99069EA20>
# 	 padding :  valid
# 	 Filters :  1024  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 256, 1024)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9906C8898>
# -------------------------------------------
# >layer 109 : name : bn4c_branch2c  type: <mrcnn.model.BatchNorm object at 0x000002E990688AC8>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9906C8898>
# << outbound shape[(None, 64, 64, 1024), (None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9906E1EF0>
# -------------------------------------------
# >layer 110 : name : add_76  type: <keras.layers.merge.Add object at 0x000002E9906BD9E8>
# >> input_shape [(None, 64, 64, 1024), (None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9906E1EF0>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9906E15C0>
# -------------------------------------------
# >layer 111 : name : res4c_out  type: <keras.layers.core.Activation object at 0x000002E9906D6A20>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9906E15C0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 64, 64, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9906EDAC8>
# -------------------------------------------
# >layer 112 : name : res4d_branch2a  type: <keras.layers.convolutional.Conv2D object at 0x000002E9906E1400>
# >> input_shape [(None, 64, 64, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9906EDAC8>
# 	 padding :  valid
# 	 Filters :  256  Kernel Size : (1, 1) Stride: (1, 1)  Shape (1, 1, 1024, 256)
# 	  <function linear at 0x000002E92F7A3598>
# << outbound shape[(None, 64, 64, 256)] input_shape <keras.engine.topology.Node object at 0x000002E990726438>
# -------------------------------------------
# >layer 113 : name : bn4d_branch2a  type: <mrcnn.model.BatchNorm object at 0x000002E9906FB390>
# >> input_shape [(None, 64, 64, 256)] inbound node <keras.engine.topology.Node object at 0x000002E990726438>
# ...
# -------------------------------------------
# >layer 361 : name : rpn_bbox  type: <keras.layers.merge.Concatenate object at 0x000002E993D9BE48>
# >> input_shape [(None, None, 4), (None, None, 4), (None, None, 4), (None, None, 4), (None, None, 4)] inbound node <keras.engine.topology.Node object at 0x000002E993E0C160>
# << outbound shape[(None, None, 2), (None, None, 4)] input_shape <keras.engine.topology.Node object at 0x000002E994D0BF60>
# -------------------------------------------
# >layer 362 : name : input_gt_boxes  type: <keras.engine.topology.InputLayer object at 0x000002E930D66DD8>
# >> input_shape [(None, None, 4)] inbound node <keras.engine.topology.Node object at 0x000002E98F225E10>
# << outbound shape[(None, None, 4)] input_shape <keras.engine.topology.Node object at 0x000002E930D887B8>
# -------------------------------------------
# >layer 363 : name : ROI  type: <mrcnn.model.ProposalLayer object at 0x000002E993360B70>
# >> input_shape [(None, None, 2), (None, None, 4)] inbound node <keras.engine.topology.Node object at 0x000002E994D0BF60>
# << outbound shape[(None, 2000, 4), (None, None), (None, None, 4), (None, 56, 56, None)] input_shape <keras.engine.topology.Node object at 0x000002E995576780>
# -------------------------------------------
# >layer 364 : name : input_gt_class_ids  type: <keras.engine.topology.InputLayer object at 0x000002E98F225C88>
# >> input_shape [(None, None)] inbound node <keras.engine.topology.Node object at 0x000002E930D66C18>
# << outbound shape[(None, 2000, 4), (None, None), (None, None, 4), (None, 56, 56, None)] input_shape <keras.engine.topology.Node object at 0x000002E995576780>
# -------------------------------------------
# >layer 365 : name : lambda_7  type: <keras.layers.core.Lambda object at 0x000002E98F24DAC8>
# >> input_shape [(None, None, 4)] inbound node <keras.engine.topology.Node object at 0x000002E930D887B8>
# << outbound shape[(None, 2000, 4), (None, None), (None, None, 4), (None, 56, 56, None)] input_shape <keras.engine.topology.Node object at 0x000002E995576780>
# -------------------------------------------
# >layer 366 : name : input_gt_masks  type: <keras.engine.topology.InputLayer object at 0x000002E98F24D7B8>
# >> input_shape [(None, 56, 56, None)] inbound node <keras.engine.topology.Node object at 0x000002E98F2259E8>
# << outbound shape[(None, 2000, 4), (None, None), (None, None, 4), (None, 56, 56, None)] input_shape <keras.engine.topology.Node object at 0x000002E995576780>
# -------------------------------------------
# >layer 367 : name : proposal_targets  type: <mrcnn.model.DetectionTargetLayer object at 0x000002E994CDFEF0>
# >> input_shape [(None, 2000, 4), (None, None), (None, None, 4), (None, 56, 56, None)] inbound node <keras.engine.topology.Node object at 0x000002E995576780>
# << outbound shape[(None, 200, 4), (None, 256, 256, 256), (None, 128, 128, 256), (None, 64, 64, 256), (None, 32, 32, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99568F9B0>
# -------------------------------------------
# >layer 368 : name : roi_align_mask  type: <mrcnn.model.PyramidROIAlign object at 0x000002E9957C67B8>
# >> input_shape [(None, 200, 4), (None, 256, 256, 256), (None, 128, 128, 256), (None, 64, 64, 256), (None, 32, 32, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9959049E8>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995939BE0>
# -------------------------------------------
# >layer 369 : name : mrcnn_mask_conv1  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E9958BFEB8>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995939BE0>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9959778D0>
# -------------------------------------------
# >layer 370 : name : mrcnn_mask_bn1  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E9958CEE48>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9959778D0>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E99595DB70>
# -------------------------------------------
# >layer 371 : name : activation_219  type: <keras.layers.core.Activation object at 0x000002E99591FD68>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99595DB70>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9959514E0>
# -------------------------------------------
# >layer 372 : name : mrcnn_mask_conv2  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995967CF8>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9959514E0>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9959EACF8>
# -------------------------------------------
# >layer 373 : name : roi_align_classifier  type: <mrcnn.model.PyramidROIAlign object at 0x000002E994CF0C50>
# >> input_shape [(None, 200, 4), (None, 256, 256, 256), (None, 128, 128, 256), (None, 64, 64, 256), (None, 32, 32, 256)] inbound node <keras.engine.topology.Node object at 0x000002E99568F9B0>
# << outbound shape[(None, 200, 7, 7, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9956C5DD8>
# -------------------------------------------
# >layer 374 : name : mrcnn_mask_bn2  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E99599FEB8>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9959EACF8>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9959B7C18>
# -------------------------------------------
# >layer 375 : name : mrcnn_class_conv1  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995649E80>
# >> input_shape [(None, 200, 7, 7, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9956C5DD8>
# << outbound shape[(None, 200, 1, 1, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E995703898>
# -------------------------------------------
# >layer 376 : name : activation_220  type: <keras.layers.core.Activation object at 0x000002E995994630>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9959B7C18>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E9959DDAC8>
# -------------------------------------------
# >layer 377 : name : mrcnn_class_bn1  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995658E10>
# >> input_shape [(None, 200, 1, 1, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E995703898>
# << outbound shape[(None, 200, 1, 1, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9956E8B38>
# -------------------------------------------
# >layer 378 : name : mrcnn_mask_conv3  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E9959CF7F0>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E9959DDAC8>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995A2D588>
# -------------------------------------------
# >layer 379 : name : activation_216  type: <keras.layers.core.Activation object at 0x000002E9956AAD30>
# >> input_shape [(None, 200, 1, 1, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9956E8B38>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 200, 1, 1, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9956DD208>
# -------------------------------------------
# >layer 380 : name : mrcnn_mask_bn3  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995A208D0>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995A2D588>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995A53DA0>
# -------------------------------------------
# >layer 381 : name : mrcnn_class_conv2  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E9956F3CC0>
# >> input_shape [(None, 200, 1, 1, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9956DD208>
# << outbound shape[(None, 200, 1, 1, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E995776CC0>
# -------------------------------------------
# >layer 382 : name : activation_221  type: <keras.layers.core.Activation object at 0x000002E995A13DA0>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995A53DA0>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995A3A908>
# -------------------------------------------
# >layer 383 : name : mrcnn_class_bn2  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E99572BC88>
# >> input_shape [(None, 200, 1, 1, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E995776CC0>
# << outbound shape[(None, 200, 1, 1, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E99576AA90>
# -------------------------------------------
# >layer 384 : name : mrcnn_mask_conv4  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995A087F0>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995A3A908>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995AC75F8>
# -------------------------------------------
# >layer 385 : name : activation_217  type: <keras.layers.core.Activation object at 0x000002E99571F5C0>
# >> input_shape [(None, 200, 1, 1, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E99576AA90>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 200, 1, 1, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E995742B70>
# -------------------------------------------
# >layer 386 : name : mrcnn_mask_bn4  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995A86B00>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995AC75F8>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995AA2438>
# -------------------------------------------
# >layer 387 : name : pool_squeeze  type: <keras.layers.core.Lambda object at 0x000002E99576AE80>
# >> input_shape [(None, 200, 1, 1, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E995742B70>
# << outbound shape[(None, 200, 1024)] input_shape <keras.engine.topology.Node object at 0x000002E9957A98D0>
# -------------------------------------------
# >layer 388 : name : activation_222  type: <keras.layers.core.Activation object at 0x000002E995A95D68>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995AA2438>
# 	  <function relu at 0x000002E92F7A3378>
# << outbound shape[(None, 200, 14, 14, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995B22828>
# -------------------------------------------
# >layer 389 : name : mrcnn_bbox_fc  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E99579EAC8>
# >> input_shape [(None, 200, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E995793588>
# << outbound shape[(None, 200, 324)] input_shape <keras.engine.topology.Node object at 0x000002E9957EF780>
# -------------------------------------------
# >layer 390 : name : mrcnn_mask_deconv  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995ABBB70>
# >> input_shape [(None, 200, 14, 14, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995B22828>
# << outbound shape[(None, 200, 28, 28, 256)] input_shape <keras.engine.topology.Node object at 0x000002E995B75F28>
# -------------------------------------------
# >layer 391 : name : input_image_meta  type: <keras.engine.topology.InputLayer object at 0x000002E98F21BF28>
# >> input_shape [(None, None)] inbound node <keras.engine.topology.Node object at 0x000002E930D8C438>
# << outbound shape[(None, None)] input_shape <keras.engine.topology.Node object at 0x000002E994CFBC18>
# -------------------------------------------
# >layer 392 : name : rpn_class_logits  type: <keras.layers.merge.Concatenate object at 0x000002E9933449B0>
# >> input_shape [(None, None, 2), (None, None, 2), (None, None, 2), (None, None, 2), (None, None, 2)] inbound node <keras.engine.topology.Node object at 0x000002E993D7BB00>
# << outbound shape[(None, None, 1), (None, None, 2)] input_shape <keras.engine.topology.Node object at 0x000002E995B50C88>
# -------------------------------------------
# >layer 393 : name : mrcnn_class_logits  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E99575B908>
# >> input_shape [(None, 200, 1024)] inbound node <keras.engine.topology.Node object at 0x000002E9957A98D0>
# << outbound shape[(None, 200, 81)] input_shape <keras.engine.topology.Node object at 0x000002E995793668>
# -------------------------------------------
# >layer 394 : name : mrcnn_bbox  type: <keras.layers.core.Reshape object at 0x000002E99579E5F8>
# >> input_shape [(None, 200, 324)] inbound node <keras.engine.topology.Node object at 0x000002E9957EF780>
# << outbound shape[(None, 200, 4), (None, 1), (None, 200, 81, 4)] input_shape <keras.engine.topology.Node object at 0x000002E995E31B70>
# -------------------------------------------
# >layer 395 : name : mrcnn_mask  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E995B32B38>
# >> input_shape [(None, 200, 28, 28, 256)] inbound node <keras.engine.topology.Node object at 0x000002E995B75F28>
# << outbound shape[(None, 200, 28, 28), (None, 1), (None, 200, 28, 28, 81)] input_shape <keras.engine.topology.Node object at 0x000002E995F62E80>
# -------------------------------------------
# >layer 396 : name : input_rpn_match  type: <keras.engine.topology.InputLayer object at 0x000002E98F1F7A20>
# >> input_shape [(None, None, 1)] inbound node <keras.engine.topology.Node object at 0x000002E98F1F7D68>
# << outbound shape[(None, None, 1), (None, None, 2)] input_shape <keras.engine.topology.Node object at 0x000002E995B50C88>
# -------------------------------------------
# >layer 397 : name : input_rpn_bbox  type: <keras.engine.topology.InputLayer object at 0x000002E98F1F79E8>
# >> input_shape [(None, None, 4)] inbound node <keras.engine.topology.Node object at 0x000002E98F1F7780>
# << outbound shape[(None, None, 4), (None, None, 1), (None, None, 4)] input_shape <keras.engine.topology.Node object at 0x000002E995C7BEF0>
# -------------------------------------------
# >layer 398 : name : lambda_10  type: <keras.layers.core.Lambda object at 0x000002E993344D30>
# >> input_shape [(None, None)] inbound node <keras.engine.topology.Node object at 0x000002E994CFBC18>
# << outbound shape[(None, 1), (None, 200, 81), (None, None)] input_shape <keras.engine.topology.Node object at 0x000002E995D0B518>
# -------------------------------------------
# >layer 399 : name : mrcnn_class  type: <keras.layers.wrappers.TimeDistributed object at 0x000002E99575B5F8>
# >> input_shape [(None, 200, 81)] inbound node <keras.engine.topology.Node object at 0x000002E995793668>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-121-b7b5b1503e94> in <module>()
#      19
#      20 #     pp.pprint(layer.__dict__)
# ---> 21     print("<< outbound shape{} input_shape {}".format(layer._outbound_nodes[0].input_shapes,layer._outbound_nodes[0]))
#      22 #     print('<< outbound node output_shape {}'.format(layer._outbound_nodes[0].output_shapes))
#      23     print('-------------------------------------------')
#
# IndexError: list index out of range
